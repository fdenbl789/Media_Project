# %% [markdown]
# ## Final Project Submission

# %%
# Your code here - remember to use markdown cells for comments as well!
from bs4 import BeautifulSoup
import requests
from urllib.request import urlopen
from bs4 import BeautifulSoup as soup
# https://www.boxofficemojo.com/chart/top_lifetime_gross/?area=XWW
html_page = requests.get('https://en.wikipedia.org/wiki/2010s_in_film') # Make a get request to retrieve the page
soup = BeautifulSoup(html_page.content, 'html.parser') # Pass the page contents to beautiful soup for parsing

for record in soup.findAll('tr'):
    for data in record.findAll('td'):
        print(data.text)
# Out:
# List of years in film
#
# (table)
#
#
#
# List of years in film
#
# (table)
#
#
# … 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019
# 2020 …
#
#
#
# .mw-parser-output .nobold{font-weight:normal}In home video
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
#
#
# In television
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
#
#
#
# Art
# Archaeology
# Architecture
# Literature
# Music
# Philosophy
# Science +...
#
#
#
# 1880s
# 1880
# 1881
# 1882
# 1883
# 1884
# 1885
# 1886
# 1887
# 1888
# 1889
#
# 1890s
# 1890
# 1891
# 1892
# 1893
# 1894
# 1895
# 1896
# 1897
# 1898
# 1899
#
# 1900s
# 1900
# 1901
# 1902
# 1903
# 1904
# 1905
# 1906
# 1907
# 1908
# 1909
#
# 1910s
# 1910
# 1911
# 1912
# 1913
# 1914
# 1915
# 1916
# 1917
# 1918
# 1919
#
# 1920s
# 1920
# 1921
# 1922
# 1923
# 1924
# 1925
# 1926
# 1927
# 1928
# 1929
#
# 1930s
# 1930
# 1931
# 1932
# 1933
# 1934
# 1935
# 1936
# 1937
# 1938
# 1939
#
# ...

# %%
url = 'https://www.boxofficemojo.com/chart/top_lifetime_gross/?ref_=bo_cso_ac'
html_page = requests.get(url) # Make a get request to retrieve the page
soup = BeautifulSoup(html_page.content, 'html.parser') # Pass the page contents to beautiful soup for parsing

for record in soup.findAll('tr'):
    for data in record.findAll('td'):
        print(data.text)

import numpy as np
import pandas as pd


Data_set= data.text
# Out:
# 1
# Star Wars: Episode VII - The Force Awakens
# $936,662,225
# 2015
# 2
# Avengers: Endgame
# $858,373,000
# 2019
# 3
# Avatar
# $760,507,625
# 2009
# 4
# Black Panther
# $700,059,566
# 2018
# 5
# Avengers: Infinity War
# $678,815,482
# 2018
# 6
# Titanic
# $659,363,944
# 1997
# 7
# Jurassic World
# $652,270,625
# 2015
# 8
# The Avengers
# $623,357,910
# 2012
# 9
# Star Wars: Episode VIII - The Last Jedi
# $620,181,382
# 2017
# 10
# Incredibles 2
# $608,581,744
# 2018
# 11
# The Lion King
# $543,638,043
# 2019
# 12
# The Dark Knight
# $535,234,033
# 2008
# 13
# Rogue One: A Star Wars Story
# $532,177,324
# 2016
# 14
# Star Wars: The Rise of Skywalker
# $514,684,482
# 2019
# 15
# Beauty and the Beast
# $504,014,165
# 2017
# 16
# Finding Dory
# $486,295,561
# 2016
# 17
# Frozen II
# $477,020,655
# 2019
# 18
# Star Wars: Episode I - The Phantom Menace
# $474,544,677
# 1999
# 19
# Star Wars: Episode IV - A New Hope
# $460,998,507
# 1977
# 20
# Avengers: Age of Ultron
# $459,005,868
# ...

# %%
x=(data.txt)
print(data.txt)
# Out:
# None

# %%
for header in soup.findAll('th'):
    print(header.text)
# Out:
# Rank
#
# Title
#
# Lifetime Gross
#
# Year
# str

# %%
df = pd.DataFrame
df.columns= ['Rank', 'Title', 'Lifetime Gross', 'Year']
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-145-c0a7ccf5e20a> in <module>
# ----> 1 df = pd.DataFrame(Data_set)
#       2 df.columns= ['Rank', 'Title', 'Lifetime Gross', 'Year']
#       3 df
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     483                 )
#     484             else:
# --> 485                 raise ValueError("DataFrame constructor not properly called!")
#     486
#     487         NDFrame.__init__(self, mgr, fastpath=True)
#
# ValueError: DataFrame constructor not properly called!

# %%
soup.find_all('class')
# Out:
# []

# %%
soup.find_all('wiki')
# Out:
# []

# %%
soup.prettify
# Out:
# <bound method Tag.prettify of <!DOCTYPE doctype html>
# <html class="a-no-js" data-19ax5a9jf="dingo"><head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/><meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta charset="utf-8"/>
# <title dir="ltr">Top Lifetime Grosses - Box Office Mojo</title><meta content="Top Lifetime Grosses" name="title"/>
# <meta content="Box Office Mojo" property="og:site_name"/>
# <meta content="telephone=no" name="format-detection"/>
# <link href="https://m.media-amazon.com/images/G/01/boxofficemojo/v2/favicon._CB448965889_.ico" rel="icon" type="image/x-icon"/>
# ...

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('title.akas.tsv', delimiter= '\t')
df.head(5)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-99-dd8b48dcf9dc> in <module>
# ----> 1 df = pd.read_csv('title.akas.tsv', delimiter= '\t')
#       2 df.head(5)
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# ...

# %%
url = 'https://www.the-numbers.com/movie/budgets/all'
html_page = requests.get(url) # Make a get request to retrieve the page
soup = BeautifulSoup(html_page.content, 'html.parser') # Pass the page contents to beautiful soup for parsing

for record in soup.findAll('tr'):
    for data in record.findAll('td'):
        print(data.text)                        #THIS IS production budget, domestic gross, and international gross
# Out:
# 1
# Apr 23, 2019
# Avengers: Endgame
#  $400,000,000
#  $858,373,000
#  $2,797,800,564
# 2
# May 20, 2011
# Pirates of the Caribbean: On Stranger Tides
#  $379,000,000
#  $241,063,875
#  $1,045,663,875
# 3
# Apr 22, 2015
# Avengers: Age of Ultron
#  $365,000,000
#  $459,005,868
#  $1,403,013,963
# 4
# Dec 16, 2015
# Star Wars Ep. VII: The Force Awakens
#  $306,000,000
#  $936,662,225
#  $2,068,223,624
# 5
# Apr 25, 2018
# Avengers: Infinity War
#  $300,000,000
#  $678,815,482
#  $2,048,359,754
# 6
# May 24, 2007
# Pirates of the Caribbean: At Worldâs End
#  $300,000,000
#  $309,420,425
#  $963,420,425
# 7
# Nov 13, 2017
# Justice League
#  $300,000,000
#  $229,024,295
#  $655,945,209
# 8
# Oct 6, 2015
# Spectre
#  $300,000,000
#  $200,074,175
#  $879,620,923
# 9
# Dec 18, 2019
# Star Wars: The Rise of Skywalker
#  $275,000,000
#  $514,684,482
#  $1,069,584,071
# 10
# May 23, 2018
# Solo: A Star Wars Story
#  $275,000,000
#  $213,767,512
#  $393,151,347
# 11
# Mar 7, 2012
# ...

# %%
soup.findAll('href')
# Out:
# []

# %%
url = 'https://www.boxofficemojo.com/charts/overall/?ref_=bo_nb_ydw_tab'
html_page = requests.get(url) # Make a get request to retrieve the page
soup = BeautifulSoup(html_page.content, 'html.parser') # Pass the page contents to beautiful soup for parsing

for record in soup.findAll('tr'):
    for data in record.findAll('td'):
        print(data.text)                         #
# Out:
# Top Lifetime Grosses
# Star Wars: Episode VII - The Force Awakens
# $936,662,225
# Adjusted to 2020
# Gone with the Wind
# $1,895,421,694
# G
# Toy Story 4
# $434,038,008
# G/PG
# Incredibles 2
# $608,581,744
# PG
# Incredibles 2
# $608,581,744
# PG-13
# Star Wars: Episode VII - The Force Awakens
# $936,662,225
# R
# The Passion of the Christ
# $370,782,930
# NC-17
# Last Tango in Paris
# $36,144,000
# Never #1
# Sing
# $270,395,425
# Never in the Top 5
# Space Station 3D
# $93,383,002
# Never in the Top 10
# Space Station 3D
# $93,383,002

# %%
url = 'https://www.boxofficemojo.com/chart/mpaa_title_lifetime_gross/?area=XWW&by_mpaa=PG-13'
html_page = requests.get(url) # Make a get request to retrieve the page
soup = BeautifulSoup(html_page.content, 'html.parser') # Pass the page contents to beautiful soup for parsing

for record in soup.findAll('tr'):
    for data in record.findAll('td'):
        print(data.text)
# Out:
# Avengers: Endgame
# 1
# $2,797,800,564
# 1
# 2019
# Avatar
# 2
# $2,790,439,000
# 2
# 2009
# Titanic
# 3
# $2,194,439,542
# 3
# 1997
# Star Wars: Episode VII - The Force Awakens
# 4
# $2,068,223,624
# 4
# 2015
# Avengers: Infinity War
# 5
# $2,048,359,754
# 5
# 2018
# Jurassic World
# 6
# $1,670,400,637
# 6
# 2015
# The Avengers
# 7
# $1,518,812,988
# 8
# 2012
# Furious 7
# 8
# $1,515,047,671
# 9
# 2015
# Avengers: Age of Ultron
# 9
# $1,402,805,868
# 11
# 2015
# Black Panther
# 10
# $1,346,913,161
# 12
# 2018
# Harry Potter and the Deathly Hallows: Part 2
# 11
# $1,341,932,398
# 13
# 2011
# Star Wars: Episode VIII - The Last Jedi
# 12
# $1,332,539,889
# 14
# 2017
# Jurassic World: Fallen Kingdom
# 13
# $1,308,467,944
# 15
# 2018
# The Fate of the Furious
# 14
# $1,236,005,118
# 19
# 2017
# Iron Man 3
# 15
# $1,214,811,252
# 20
# 2013
# Captain America: Civil War
# 16
# $1,153,296,293
# 22
# 2016
# Aquaman
# 17
# $1,148,461,807
# 23
# 2018
# ...

# %%
url = 'https://www.boxofficemojo.com/chart/mpaa_title_lifetime_gross/?area=XWW&by_mpaa=G'
html_page = requests.get(url) # Make a get request to retrieve the page
soup = BeautifulSoup(html_page.content, 'html.parser') # Pass the page contents to beautiful soup for parsing

for record in soup.findAll('tr'):
    for data in record.findAll('td'):
        print(data.text)
# Out:
# Toy Story 4
# 1
# $1,073,394,593
# 32
# 2019
# Toy Story 3
# 2
# $1,066,969,703
# 34
# 2010
# The Lion King
# 3
# $968,511,805
# 50
# 1994
# Finding Nemo
# 4
# $940,343,261
# 58
# 2003
# Monsters University
# 5
# $743,559,607
# 111
# 2013
# Monsters, Inc.
# 6
# $632,316,649
# 144
# 2001
# Ratatouille
# 7
# $623,726,085
# 152
# 2007
# Cars 2
# 8
# $559,852,396
# 178
# 2011
# WALL·E
# 9
# $521,311,860
# 206
# 2008
# Aladdin
# 10
# $504,050,219
# 212
# 1992
# Rio 2
# 11
# $498,781,117
# 213
# 2014
# Toy Story 2
# 12
# $497,374,776
# 215
# 1999
# Cars
# 13
# $461,983,149
# 245
# 2006
# Tarzan
# 14
# $448,191,819
# 258
# 1999
# Beauty and the Beast
# 15
# $440,118,382
# 268
# 1991
# Toy Story
# 16
# $404,265,438
# 303
# 1995
# Gone with the Wind
# 17
# $402,352,579
# 306
# 1939
# Cars 3
# 18
# $383,930,656
# 325
# 2017
# A Bug's Life
# 19
# $363,258,859
# 361
# 1998
# Pocahontas
# 20
# $346,079,773
# 405
# 1995
# Alvin and the Chipmunks: Chipwrecked
# 21
# $342,695,435
# 408
# 2011
# ...

# %%
url = 'https://www.boxofficemojo.com/chart/mpaa_title_lifetime_gross/?area=XWW&by_mpaa=G%2FPG'
html_page = requests.get(url) # Make a get request to retrieve the page
soup = BeautifulSoup(html_page.content, 'html.parser') # Pass the page contents to beautiful soup for parsing

for record in soup.findAll('tr'):
    for data in record.findAll('td'):
        print(data.text)
# Out:
# The Lion King
# 1
# $1,656,943,394
# 7
# 2019
# Frozen II
# 2
# $1,448,800,077
# 10
# 2019
# Frozen
# 3
# $1,280,802,282
# 16
# 2013
# Beauty and the Beast
# 4
# $1,263,521,126
# 17
# 2017
# Incredibles 2
# 5
# $1,242,805,359
# 18
# 2018
# Minions
# 6
# $1,159,398,397
# 21
# 2015
# Toy Story 4
# 7
# $1,073,394,593
# 32
# 2019
# Toy Story 3
# 8
# $1,066,969,703
# 34
# 2010
# Aladdin
# 9
# $1,050,693,953
# 37
# 2019
# Despicable Me 3
# 10
# $1,034,799,409
# 39
# 2017
# Finding Dory
# 11
# $1,028,570,889
# 41
# 2016
# Star Wars: Episode I - The Phantom Menace
# 12
# $1,027,082,707
# 42
# 1999
# Alice in Wonderland
# 13
# $1,025,467,110
# 43
# 2010
# Zootopia
# 14
# $1,023,784,195
# 44
# 2016
# Harry Potter and the Sorcerer's Stone
# 15
# $978,087,613
# 47
# 2001
# Despicable Me 2
# 16
# $970,766,005
# 49
# 2013
# The Lion King
# 17
# $968,511,805
# 50
# 1994
# The Jungle Book
# 18
# $966,550,600
# 51
# 2016
# Finding Nemo
# 19
# $940,343,261
# 58
# 2003
# ...

# %%
url = 'https://www.boxofficemojo.com/chart/mpaa_title_lifetime_gross/?area=XWW&by_mpaa=PG'
html_page = requests.get(url) # Make a get request to retrieve the page
soup = BeautifulSoup(html_page.content, 'html.parser') # Pass the page contents to beautiful soup for parsing

for record in soup.findAll('tr'):
    for data in record.findAll('td'):
        print(data.text)
# Out:
# The Lion King
# 1
# $1,656,943,394
# 7
# 2019
# Frozen II
# 2
# $1,448,800,077
# 10
# 2019
# Frozen
# 3
# $1,280,802,282
# 16
# 2013
# Beauty and the Beast
# 4
# $1,263,521,126
# 17
# 2017
# Incredibles 2
# 5
# $1,242,805,359
# 18
# 2018
# Minions
# 6
# $1,159,398,397
# 21
# 2015
# Aladdin
# 7
# $1,050,693,953
# 37
# 2019
# Despicable Me 3
# 8
# $1,034,799,409
# 39
# 2017
# Finding Dory
# 9
# $1,028,570,889
# 41
# 2016
# Star Wars: Episode I - The Phantom Menace
# 10
# $1,027,082,707
# 42
# 1999
# Alice in Wonderland
# 11
# $1,025,467,110
# 43
# 2010
# Zootopia
# 12
# $1,023,784,195
# 44
# 2016
# Harry Potter and the Sorcerer's Stone
# 13
# $978,087,613
# 47
# 2001
# Despicable Me 2
# 14
# $970,766,005
# 49
# 2013
# The Jungle Book
# 15
# $966,550,600
# 51
# 2016
# Harry Potter and the Half-Blood Prince
# 16
# $934,326,396
# 59
# 2009
# Shrek 2
# 17
# $928,760,770
# 60
# 2004
# Ice Age: Dawn of the Dinosaurs
# 18
# $886,686,817
# 65
# 2009
# Harry Potter and the Chamber of Secrets
# ...

# %%
url = 'https://www.boxofficemojo.com/chart/top_lifetime_gross_adjusted/?adjust_gross_to=2020&ref_=bo_cso_ac'
html_page = requests.get(url) # Make a get request to retrieve the page
soup = BeautifulSoup(html_page.content, 'html.parser') # Pass the page contents to beautiful soup for parsing

for record in soup.findAll('tr'):
    for data in record.findAll('td'):
        print(data.text)
# Out:
# 1
# Gone with the Wind
# $1,895,421,694
# $200,852,579
# 202,286,200
# 1939
# 2
# Star Wars: Episode IV - A New Hope
# $1,668,979,715
# $460,998,507
# 178,119,500
# 1977
# 3
# The Sound of Music
# $1,335,086,324
# $159,287,539
# 142,485,200
# 1965
# 4
# E.T. the Extra-Terrestrial
# $1,329,174,791
# $435,110,554
# 141,854,300
# 1982
# 5
# Titanic
# $1,270,101,626
# $659,363,944
# 135,549,800
# 1997
# 6
# The Ten Commandments
# $1,227,470,000
# $65,500,000
# 131,000,000
# 1956
# 7
# Jaws
# $1,200,098,356
# $260,000,000
# 128,078,800
# 1975
# 8
# Doctor Zhivago
# $1,163,149,635
# $111,721,910
# 124,135,500
# 1965
# 9
# The Exorcist
# $1,036,314,504
# $232,906,145
# 110,599,200
# 1973
# 10
# Snow White and the Seven Dwarfs
# $1,021,330,000
# $184,925,486
# 109,000,000
# 1937
# 11
# Star Wars: Episode VII - The Force Awakens
# $1,013,038,487
# $936,662,225
# 108,115,100
# 2015
# 12
# One Hundred and One Dalmatians
# $936,225,101
# $144,880,014
# 99,917,300
# 1961
# 13
# ...

# %%
# Out:
# str
